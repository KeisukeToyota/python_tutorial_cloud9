# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df= pd.read_csv("train.csv").replace("male",0).replace("female",1)

# %%
df= pd.read_csv("train.csv").replace("male",0).replace("female",1)
df["Age"].fillna(df.Age.mean(), inplace=True)

# %%
temp = [i["Sex"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=2)
# Out:
# ([array([ 468.,   81.]), array([ 577.,  314.])],
#  array([ 0. ,  0.5,  1. ]),
#  <a list of 2 Lists of Patches objects>)

# %%
df.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 271          272         1       3
# 597          598         0       3
# 302          303         0       3
# 633          634         0       1
# 277          278         0       2
# 413          414         0       2
# 674          675         0       2
# 263          264         0       1
# 466          467         0       2
# 732          733         0       2
# 179          180         0       3
# 806          807         0       1
# 481          482         0       2
# 822          823         0       1
# 815          816         0       1
# 378          379         0       3
# 872          873         0       1
# 326          327         0       3
# 843          844         0       3
# 818          819         0       3
# 371          372         0       3
# 202          203         0       3
# 654          655         0       3
# 143          144         0       3
# 411          412         0       3
# 825          826         0       3
# 129          130         0       3
# 804          805         1       3
# 477          478         0       3
# 611          612         0       3
# ..           ...       ...     ...
# 31            32         1       1
# 708          709         1       1
# 498          499         0       1
# 305          306         1       1
# 297          298         0       1
# 609          610         1       1
# 332          333         0       1
# 268          269         1       1
# 856          857         1       1
# 318          319         1       1
# 779          780         1       1
# 730          731         1       1
# 689          690         1       1
# 377          378         0       1
# 527          528         0       1
# 700          701         1       1
# 380          381         1       1
# 557          558         0       1
# 716          717         1       1
# 118          119         0       1
# 299          300         1       1
# 742          743         1       1
# 311          312         1       1
# 27            28         0       1
# 88            89         1       1
# 438          439         0       1
# 341          342         1       1
# 737          738         1       1
# 258          259         1       1
# 679          680         1       1
#
#                                                   Name  Sex        Age  SibSp  \
# 271                       Tornquist, Mr. William Henry    0  25.000000      0
# 597                                Johnson, Mr. Alfred    0  49.000000      0
# 302                    Johnson, Mr. William Cahoone Jr    0  19.000000      0
# 633                      Parr, Mr. William Henry Marsh    0  29.699118      0
# 277                        Parkes, Mr. Francis "Frank"    0  29.699118      0
# 413                     Cunningham, Mr. Alfred Fleming    0  29.699118      0
# 674                         Watson, Mr. Ennis Hastings    0  29.699118      0
# 263                              Harrison, Mr. William    0  40.000000      0
# 466                              Campbell, Mr. William    0  29.699118      0
# 732                               Knight, Mr. Robert J    0  29.699118      0
# 179                                Leonard, Mr. Lionel    0  36.000000      0
# 806                             Andrews, Mr. Thomas Jr    0  39.000000      0
# 481                   Frost, Mr. Anthony Wood "Archie"    0  29.699118      0
# 822                    Reuchlin, Jonkheer. John George    0  38.000000      0
# 815                                   Fry, Mr. Richard    0  29.699118      0
# 378                                Betros, Mr. Tannous    0  20.000000      0
# 872                           Carlsson, Mr. Frans Olof    0  33.000000      0
# 326                          Nysveen, Mr. Johan Hansen    0  61.000000      0
# 843                         Lemberopolous, Mr. Peter L    0  34.500000      0
# 818                   Holm, Mr. John Fredrik Alexander    0  43.000000      0
# 371                          Wiklund, Mr. Jakob Alfred    0  18.000000      1
# 202                         Johanson, Mr. Jakob Alfred    0  34.000000      0
# 654                       Hegarty, Miss. Hanora "Nora"    1  18.000000      0
# 143                                Burke, Mr. Jeremiah    0  19.000000      0
# 411                                    Hart, Mr. Henry    0  29.699118      0
# 825                                    Flynn, Mr. John    0  29.699118      0
# 129                                 Ekstrom, Mr. Johan    0  45.000000      0
# 804                            Hedman, Mr. Oskar Arvid    0  27.000000      0
# 477                          Braund, Mr. Lewis Richard    0  29.000000      1
# 611                              Jardin, Mr. Jose Neto    0  29.699118      0
# ..                                                 ...  ...        ...    ...
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)    1  29.699118      1
# 708                               Cleaver, Miss. Alice    1  22.000000      0
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1  25.000000      1
# 305                     Allison, Master. Hudson Trevor    0   0.920000      1
# 297                       Allison, Miss. Helen Loraine    1   2.000000      1
# 609                          Shutes, Miss. Elizabeth W    1  40.000000      0
# 332                          Graham, Mr. George Edward    0  38.000000      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)    1  58.000000      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)    1  45.000000      1
# 318                           Wick, Miss. Mary Natalie    1  31.000000      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...    1  43.000000      0
# 730                      Allen, Miss. Elisabeth Walton    1  29.000000      0
# 689                  Madill, Miss. Georgette Alexandra    1  15.000000      0
# 377                          Widener, Mr. Harry Elkins    0  27.000000      0
# 527                                 Farthing, Mr. John    0  29.699118      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)    1  18.000000      1
# 380                              Bidois, Miss. Rosalie    1  42.000000      0
# 557                                Robbins, Mr. Victor    0  29.699118      0
# 716                      Endres, Miss. Caroline Louise    1  38.000000      0
# 118                           Baxter, Mr. Quigg Edmond    0  24.000000      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)    1  50.000000      0
# 742              Ryerson, Miss. Susan Parker "Suzette"    1  21.000000      2
# 311                         Ryerson, Miss. Emily Borie    1  18.000000      2
# 27                      Fortune, Mr. Charles Alexander    0  19.000000      3
# 88                          Fortune, Miss. Mabel Helen    1  23.000000      3
# 438                                  Fortune, Mr. Mark    0  64.000000      1
# 341                     Fortune, Miss. Alice Elizabeth    1  24.000000      3
# 737                             Lesurer, Mr. Gustave J    0  35.000000      0
# 258                                   Ward, Miss. Anna    1  35.000000      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    0  36.000000      0
#
#      Parch              Ticket      Fare            Cabin Embarked
# 271      0                LINE    0.0000              NaN        S
# 597      0                LINE    0.0000              NaN        S
# 302      0                LINE    0.0000              NaN        S
# 633      0              112052    0.0000              NaN        S
# 277      0              239853    0.0000              NaN        S
# 413      0              239853    0.0000              NaN        S
# 674      0              239856    0.0000              NaN        S
# 263      0              112059    0.0000              B94        S
# 466      0              239853    0.0000              NaN        S
# 732      0              239855    0.0000              NaN        S
# 179      0                LINE    0.0000              NaN        S
# 806      0              112050    0.0000              A36        S
# 481      0              239854    0.0000              NaN        S
# 822      0               19972    0.0000              NaN        S
# 815      0              112058    0.0000             B102        S
# 378      0                2648    4.0125              NaN        C
# 872      0                 695    5.0000      B51 B53 B55        S
# 326      0              345364    6.2375              NaN        S
# 843      0                2683    6.4375              NaN        C
# 818      0              C 7075    6.4500              NaN        S
# 371      0             3101267    6.4958              NaN        S
# 202      0             3101264    6.4958              NaN        S
# 654      0              365226    6.7500              NaN        Q
# 143      0              365222    6.7500              NaN        Q
# 411      0              394140    6.8583              NaN        Q
# 825      0              368323    6.9500              NaN        Q
# 129      0              347061    6.9750              NaN        S
# 804      0              347089    6.9750              NaN        S
# 477      0                3460    7.0458              NaN        S
# 611      0  SOTON/O.Q. 3101305    7.0500              NaN        S
# ..     ...                 ...       ...              ...      ...
# 31       0            PC 17569  146.5208              B78        C
# 708      0              113781  151.5500              NaN        S
# 498      2              113781  151.5500          C22 C26        S
# 305      2              113781  151.5500          C22 C26        S
# 297      2              113781  151.5500          C22 C26        S
# 609      0            PC 17582  153.4625             C125        S
# 332      1            PC 17582  153.4625              C91        S
# 268      1            PC 17582  153.4625             C125        S
# 856      1               36928  164.8667              NaN        S
# 318      2               36928  164.8667               C7        S
# 779      1               24160  211.3375               B3        S
# 730      0               24160  211.3375               B5        S
# 689      1               24160  211.3375               B5        S
# 377      2              113503  211.5000              C82        C
# 527      0            PC 17483  221.7792              C95        S
# 700      0            PC 17757  227.5250          C62 C64        C
# 380      0            PC 17757  227.5250              NaN        C
# 557      0            PC 17757  227.5250              NaN        C
# 716      0            PC 17757  227.5250              C45        C
# 118      1            PC 17558  247.5208          B58 B60        C
# 299      1            PC 17558  247.5208          B58 B60        C
# 742      2            PC 17608  262.3750  B57 B59 B63 B66        C
# 311      2            PC 17608  262.3750  B57 B59 B63 B66        C
# 27       2               19950  263.0000      C23 C25 C27        S
# 88       2               19950  263.0000      C23 C25 C27        S
# 438      4               19950  263.0000      C23 C25 C27        S
# 341      2               19950  263.0000      C23 C25 C27        S
# 737      0            PC 17755  512.3292             B101        C
# 258      0            PC 17755  512.3292              NaN        C
# 679      1            PC 17755  512.3292      B51 B53 B55        C
#
# [891 rows x 12 columns]

# %%
split_data = []
for survived in [0,1]:
    split_data.append(df[df.Survived==survived])
    
temp = [i["Pclass"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=3)
# Out:
# ([array([  80.,   97.,  372.]), array([ 216.,  184.,  491.])],
#  array([ 1.        ,  1.66666667,  2.33333333,  3.        ]),
#  <a list of 2 Lists of Patches objects>)

# %%
min(df.Age)
# Out:
# 0.41999999999999998

# %%
df["Age"].fillna(df.Age.mean(), inplace=True)

# %%
temp = [i["Age"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=16)
# Out:
# ([array([ 13.,  13.,   8.,  63.,  80.,  66.,  47.,  39.,  30.,  23.,  14.,
#           11.,  10.,   3.,   4.,   0.]),
#   array([  44.,   20.,   19.,   96.,  122.,  108.,   88.,   67.,   47.,
#            39.,   24.,   18.,   14.,    3.,    4.,    1.])],
#  array([  0.42   ,   5.39375,  10.3675 ,  15.34125,  20.315  ,  25.28875,
#          30.2625 ,  35.23625,  40.21   ,  45.18375,  50.1575 ,  55.13125,
#          60.105  ,  65.07875,  70.0525 ,  75.02625,  80.     ]),
#  <a list of 2 Lists of Patches objects>)

# %%
temp = [i["Age"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=16)
# Out:
# ([array([  13.,   13.,    8.,   63.,   80.,  191.,   47.,   39.,   30.,
#            23.,   14.,   11.,   10.,    3.,    4.,    0.]),
#   array([  44.,   20.,   19.,   96.,  122.,  285.,   88.,   67.,   47.,
#            39.,   24.,   18.,   14.,    3.,    4.,    1.])],
#  array([  0.42   ,   5.39375,  10.3675 ,  15.34125,  20.315  ,  25.28875,
#          30.2625 ,  35.23625,  40.21   ,  45.18375,  50.1575 ,  55.13125,
#          60.105  ,  65.07875,  70.0525 ,  75.02625,  80.     ]),
#  <a list of 2 Lists of Patches objects>)

# %%
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1
df2 = df.drop(["Name", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"], axis=1)

# %%
train_data = df2.values
xs = train_data[:, 2:] # Pclass以降の変数
y  = train_data[:, 1]  # 正解データ

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)

# 学習
forest = forest.fit(xs, y)

test_df= pd.read_csv("test.csv").replace("male",0).replace("female",1)

# 欠損値の補完
# test_df.dropna(subset=['Age'], inplace=True)
test_df["Age"].fillna(df.Age.median(), inplace=True)
test_df["FamilySize"] = test_df["SibSp"] + test_df["Parch"] + 1
test_df2 = test_df.drop(["Name", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked", 'Pclass'], axis=1)

# %%
print(df2.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Sex              int64
# Age            float64
# FamilySize       int64
# dtype: object

# %%
test_data = test_df2.values
xs_test = test_data[:, 1:]
output = forest.predict(xs_test)

print(len(test_data[:,0]), len(output))
zip_data = zip(test_data[:,0].astype(int), output.astype(int))
predict_data = list(zip_data)
# Out:
# 418 418

# %%
import csv
with open("predict_result_data.csv", "w") as f:
    writer = csv.writer(f, lineterminator='\n')
    writer.writerow(["PassengerId", "Survived"])
    for pid, survived in zip(test_data[:,0].astype(int), output.astype(int)):
        writer.writerow([pid, survived])
